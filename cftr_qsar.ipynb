# %%
# ================================================
# CFTR QSAR PIPELINE - GITHUB CLEAN VERSION
# No widgets - renders perfectly on GitHub
# ================================================

# 1. Install
# !pip install rdkit pandas numpy scikit-learn xgboost matplotlib seaborn -q

print("✅ Installation complete!")

# 2. Imports
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, AllChem
from rdkit.Chem.Scaffolds import MurckoScaffold
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error
import xgboost as xgb
from io import StringIO
import warnings
warnings.filterwarnings('ignore')

print("✅ Libraries loaded!")

# ====================== 13 CFTR HITS FROM YOUR mmc1.pdf ======================
csv_data = """Compound_ID,Activity_Fold,Class
Z2075279358,2.38,Potentiator
Z2194302854,1.39,Potentiator
Z1343848401,1.37,Potentiator
Z2776419998,1.36,Potentiator
Z1224795288,1.34,Potentiator
Z19702639,1.32,Potentiator
Z1096199008,1.30,Potentiator
Z873519648,1.27,Potentiator
Z1783799713,1.25,Potentiator
Z899051432,1.24,Potentiator
Z1262422554,1.17,Potentiator
Z2171315755,1.17,Potentiator
Z995908944,1.15,Potentiator
"""

df = pd.read_csv(StringIO(csv_data))
df['pActivity'] = np.log10(df['Activity_Fold'])

print(f"\nLoaded {len(df)} CFTR primary hits from mmc1.pdf")
print(df[['Compound_ID', 'Activity_Fold']])

# ====================== DESCRIPTORS + FINGERPRINTS ======================
# (SMILES missing - model is limited until you add them)
print("\n⚠️ SMILES are not yet added. Full modeling requires SMILES.")

# Placeholder - when you add SMILES, uncomment the lines below
# df['Mol'] = df['SMILES'].apply(Chem.MolFromSmiles)
# ... (rest of modeling code)

print("\nCurrent status: Dataset ready. Add SMILES to enable full QSAR modeling.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.0/37.0 MB 27.6 MB/s eta 0:00:00
# ✅ Installation complete!
# ✅ Libraries loaded!
#
# Loaded 13 CFTR primary hits from mmc1.pdf
#     Compound_ID  Activity_Fold
# 0   Z2075279358           2.38
# 1   Z2194302854           1.39
# 2   Z1343848401           1.37
# 3   Z2776419998           1.36
# 4   Z1224795288           1.34
# 5     Z19702639           1.32
# 6   Z1096199008           1.30
# 7    Z873519648           1.27
# 8   Z1783799713           1.25
# 9    Z899051432           1.24
# 10  Z1262422554           1.17
# 11  Z2171315755           1.17
# 12   Z995908944           1.15
#
# ⚠️ SMILES are not yet added. Full modeling requires SMILES.
#
# Current status: Dataset ready. Add SMILES to enable full QSAR modeling.
